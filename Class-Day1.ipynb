# %% [markdown]
# # ATM Booth

# %%
class ATM: 

    def __init__(self):   # constructor
        self.pin = None   
        self.balance = 0
        self.menu()       #for our purpose we need to create a method inside constructor

    def menu(self):    #Method 1
        user_input = input("""
Hello, How would you like to proceed?
1. Enter 1 to create pin
2. Enter 2 to deposit
3. Enter 3 to withdraw
4. Enter 4 to check balance
5. Enter 5 to exit
""")

        if user_input == '1': 
            self.create_pin()

        elif user_input == '2': 
            self.deposit()

        elif user_input == '3': 
            self.withdraw()

        elif user_input == '4': 
            self.check_balance()

        else:
            print("Exit")

    def create_pin(self):      #method 2
        self.pin = input('Enter your pin ') 
        print("Pin set successfully") 
        
    def deposit(self):         #method 3
        temp= input("Enter your pin ") 
        if temp == self.pin: 
            amount = int(input("Enter amount "))
            self.balance += amount 
            print("Deposit successful \n")
            print("Your new balance is ",self.balance)
        else: 
            print("Sorry, Invalid Pin!")
            
    def withdraw(self):       #method 4
        temp = input("Enter your pin ")
        if temp == self.pin : 
            amount = int(input('Enter the amount')) 
            if amount <= self.balance: 
                self.balance -= amount 
                print("Operation Successful")
            else: 
                print("Insufficient Balance ")
        else: 
            print("Sorry, Invalid Pin!") 

    def check_balance(self):  #method 5
        temp = input("Enter your pin ")
        if temp == self.pin :
            print("Your balance is ", self.balance)

# %%
atm=ATM()
# Out:
# Hello, How would you like to proceed?
# 1. Enter 1 to create pin
# 2. Enter 2 to deposit
# 3. Enter 3 to withdraw
# 4. Enter 4 to check balance
# 5. Enter 5 to exit
#  1
# Create Pin
# Enter your pin  1234
# Pin set successfully

# %%
atm.deposit()
# Out:
# Enter your pin  1234
# Enter amount  20000
# Deposit successful
#
# Your new balance is  20000

# %%
atm.check_balance()
# Out:
# Enter your pin  1234
# Your balance is  20000

# %%
atm.withdraw()
# Out:
# Enter your pin  1234
# Enter the amount 1000
# Operation Successful

# %%
atm.check_balance()
# Out:
# Enter your pin  1234
# Your balance is  19000
